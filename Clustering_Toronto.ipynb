# %%
# !pip install beautifulsoup4
# !pip install lxml
# !conda install -c conda-forge folium=0.5.0 --yes
import pandas as pd 
import numpy as np 
import requests 
import random 
import folium 
import matplotlib.cm as cm
import matplotlib.colors as colors
from IPython.display import Image 
from IPython.core.display import HTML
from IPython.display import display_html
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim 
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...

# %%
wiki_toronto = requests.get('http://zims-en.kiwix.campusafrica.gos.orange.com/wikipedia_en_all_nopic/A/List_of_postal_codes_of_Canada:_M').text
wiki_toronto=BeautifulSoup(wiki_toronto,'lxml')
table_data_toronto = str(wiki_toronto.table)
display_html(table_data_toronto,raw=True)
df_toronto = pd.read_html(table_data_toronto)
df_toronto=df_toronto[0]
# Out:
# <table class="wikitable sortable">
# <tbody><tr><th>Postcode</th><th>Borough</th><th>Neighbourhood</th></tr>
# <tr>
# <td>M1A</td><td>Not assigned</td><td>Not assigned</td></tr>
# <tr>
# <td>M2A</td><td>Not assigned</td><td>Not assigned</td></tr>
# <tr>
# <td>M3A</td><td><a href="North_York" title="North York">North York</a></td><td><a href="Parkwoods" title="Parkwoods">Parkwoods</a></td></tr>
# <tr>
# <td>M4A</td><td><a href="North_York" title="North York">North York</a></td><td><a href="Victoria_Village" title="Victoria Village">Victoria Village</a></td></tr>
# <tr>
# <td>M5A</td><td><a href="Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td><td><a href="Regent_Park" title="Regent Park">Harbourfront</a></td></tr>
# <tr>
# <td>M6A</td><td><a href="North_York" title="North York">North York</a></td><td><a href="Lawrence_Heights" title="Lawrence Heights">Lawrence Heights</a></td></tr>
# <tr>
# ...

# %%
df_toronto.shape
# Out:
# (288, 3)

# %%
# Dropping 'Not assigned' rows
df_toronto.drop(df_toronto[df_toronto['Borough'] == 'Not assigned'].index, inplace = True)
df_toronto.shape
# Out:
# (211, 3)

# %%
df_toronto.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %%
ll_data = pd.read_csv('https://cocl.us/Geospatial_data')
ll_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
ll_data.rename(columns={'Postal Code':'Postcode'},inplace=True)
#Torento Neighbourhood data with LL data
df_toronto_2 = pd.merge(df_toronto,ll_data,on='Postcode')
df_toronto_2.head()
# Out:
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 0      M3A        North York         Parkwoods  43.753259 -79.329656
# 1      M4A        North York  Victoria Village  43.725882 -79.315572
# 2      M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3      M6A        North York  Lawrence Heights  43.718518 -79.464763
# 4      M6A        North York    Lawrence Manor  43.718518 -79.464763

# %%
df_toronto_2.shape
# Out:
# (210, 5)

# %%
toronto_geo = folium.Map(location=[43.651070,-79.347015],zoom_start=11)

for latitude,longitude,borough,neighbourhood in zip(df_toronto_2['Latitude'],df_toronto_2['Longitude'],df_toronto_2['Borough'],df_toronto_2['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [latitude,longitude],
    radius=5,
    popup=label,
    color='green',
    fill=True,
    fill_color='green',
    fill_opacity=0.6,
    parse_html=False).add_to(toronto_geo)
toronto_geo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
k=5
toronto_clustering = df_toronto_2.drop(['Postcode','Borough','Neighbourhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(toronto_clustering)
kmeans.labels_
df_toronto_2.insert(0, 'Cluster_Labels', kmeans.labels_)

# %%
# create map
map_clusters = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for latitude, longitude, neighbourhood, cluster in zip(df_toronto_2['Latitude'], df_toronto_2['Longitude'], df_toronto_2['Neighbourhood'], df_toronto_2['Cluster_Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
df_toronto_2
# Out:
#      Cluster_Labels Postcode           Borough             Neighbourhood  \
# 0                 3      M3A        North York                 Parkwoods
# 1                 3      M4A        North York          Victoria Village
# 2                 1      M5A  Downtown Toronto              Harbourfront
# 3                 4      M6A        North York          Lawrence Heights
# 4                 4      M6A        North York            Lawrence Manor
# ..              ...      ...               ...                       ...
# 205               2      M8Z         Etobicoke  Kingsway Park South West
# 206               2      M8Z         Etobicoke                 Mimico NW
# 207               2      M8Z         Etobicoke        The Queensway West
# 208               2      M8Z         Etobicoke     Royal York South West
# 209               2      M8Z         Etobicoke            South of Bloor
#
#       Latitude  Longitude
# 0    43.753259 -79.329656
# 1    43.725882 -79.315572
# ...
